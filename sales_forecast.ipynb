# %%
import pandas as pd

df = pd.read_csv(
    r"C:\FUTURE_ML_01\data\Sample_Superstore.csv",
    encoding="latin1"
)
 print(df.head())
# Out:
# 14:25:23 - cmdstanpy - INFO - Chain [1] start processing
# 14:25:23 - cmdstanpy - INFO - Chain [1] done processing
